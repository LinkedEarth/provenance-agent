# %% [markdown]
# @agent code open /Ocn-Palmyra.Nurhati.2011.lpd using pylipd

# %%
# Initializes a LiPD object and loads the specified .lpd file into it. The loaded dataset will be stored within the `D` object, allowing further access and manipulation using pylipd functions.
# Auto-generated by PaleoPal CodeGenerationAgent with contextual search

# Import the LiPD class from the pylipd library
from pylipd.lipd import LiPD

# Initialize a LiPD object
D = LiPD()

# Define the path to the .lpd file
data_path = 'Ocn-Palmyra.Nurhati.2011.lpd'

# Load the .lpd file into the LiPD object
D.load(data_path)
# Out:
# Loading 1 LiPD files
# 100%|██████████| 1/1 [00:00<00:00, 19.03it/s]
# Loaded..
