# %% [markdown]
# # Sample Paleoclimate Notebook
# A minimal notebook for testing the provenance agent parser.

# %%
import numpy as np
import pandas as pd
import pyleoclim as pyleo

# %% [markdown]
# ## Load Data
# Load a sample dataset for analysis.

# %%
df = pd.DataFrame({'time': range(10), 'value': np.random.randn(10)})
df.head()
# Out:
#    time     value
# 0     0  0.730325
# 1     1  0.058726
# 2     2  0.321321
# 3     3 -0.254084
# 4     4  1.371487

# %% [markdown]
# ## Plot
# Visualize the time series.

# %%
import matplotlib.pyplot as plt

plt.plot(df['time'], df['value'])
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
