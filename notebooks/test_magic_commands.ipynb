# %% [markdown]
# # Magic Command Test Notebook
# Tests that imports are still extracted when cells contain IPython magic or shell commands.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# !pip install pyleoclim
import pyleoclim as pyleo
# Out:
# Requirement already satisfied: pyleoclim in /opt/anaconda3/envs/science/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: pandas>=2.1.4 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (3.0.3)
# Requirement already satisfied: kneed>=0.7.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.8.6)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.14.6)
# Requirement already satisfied: seaborn>=0.13.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (1.9.0)
# Requirement already satisfied: pathos>=0.2.8 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.3.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (4.68.2)
# Requirement already satisfied: wget>=3.2 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (3.2)
# Requirement already satisfied: numba>=0.56 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.65.1)
# Requirement already satisfied: nitime>=0.9 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.12.1)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.10.0)
# Requirement already satisfied: cartopy>=0.22.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (0.25.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (4.15.0)
# Requirement already satisfied: scipy>=1.15.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (1.17.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyleoclim) (2.34.2)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (2.4.6)
# Requirement already satisfied: matplotlib>=3.6 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (3.10.9)
# Requirement already satisfied: shapely>=2.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (2.1.2)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (26.0)
# Requirement already satisfied: pyshp>=2.3 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (3.0.9)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from cartopy>=0.22.0->pyleoclim) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from numba>=0.56->pyleoclim) (0.47.0)
# Requirement already satisfied: ppft>=1.7.8 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pathos>=0.2.8->pyleoclim) (1.7.8)
# Requirement already satisfied: dill>=0.4.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pathos>=0.2.8->pyleoclim) (0.4.1)
# Requirement already satisfied: pox>=0.3.7 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pathos>=0.2.8->pyleoclim) (0.3.7)
# Requirement already satisfied: multiprocess>=0.70.19 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pathos>=0.2.8->pyleoclim) (0.70.19)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from pyproj>=3.3.1->cartopy>=0.22.0->pyleoclim) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from scikit-learn>=0.24.2->pyleoclim) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from scikit-learn>=0.24.2->pyleoclim) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from scikit-learn>=0.24.2->pyleoclim) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from statsmodels>=0.13.2->pyleoclim) (1.0.2)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from beautifulsoup4->pyleoclim) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from beautifulsoup4->pyleoclim) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from requests->pyleoclim) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from requests->pyleoclim) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/science/lib/python3.12/site-packages (from requests->pyleoclim) (2.7.0)

# %%
# %%time
import scipy.stats as stats
x = stats.norm.rvs(size=100)
